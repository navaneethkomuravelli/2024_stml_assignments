# %% [markdown]
# <a href="https://colab.research.google.com/github/navaneethkomuravelli/2024_stml_assignments/blob/main/2303A52374_sml_assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/content/train.csv")
print(data)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
y=data['price_range']
y
# Out:
# 0       1
# 1       2
# 2       2
# 3       2
# 4       1
#        ..
# 1995    0
# 1996    2
# 1997    3
# 1998    0
# 1999    3
# Name: price_range, Length: 2000, dtype: int64

# %%
x=data.drop('price_range' , axis=1)
x
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
n=x-x.min()/x.max()-x.min()
n
# Out:
#       battery_power  blue  clock_speed  dual_sim    fc  four_g  int_memory  \
# 0        340.749249   0.0     1.533333       0.0   1.0     0.0     4.96875
# 1        519.749249   1.0    -0.166667       1.0   0.0     1.0    50.96875
# 2         61.749249   1.0    -0.166667       1.0   2.0     1.0    38.96875
# 3        113.749249   1.0     1.833333       0.0   0.0     0.0     7.96875
# 4       1319.749249   1.0     0.533333       0.0  13.0     1.0    41.96875
# ...             ...   ...          ...       ...   ...     ...         ...
# 1995     292.749249   1.0    -0.166667       1.0   0.0     1.0    -0.03125
# 1996    1463.749249   1.0     1.933333       1.0   0.0     0.0    36.96875
# 1997    1409.749249   0.0     0.233333       1.0   1.0     1.0    33.96875
# 1998    1010.749249   0.0     0.233333       0.0   4.0     1.0    43.96875
# 1999       8.749249   1.0     1.333333       1.0   5.0     1.0    42.96875
#
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=30)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 1572            895     0          0.5         1   6       0          16
# 1442            973     0          0.5         1   5       0          53
# 1516           1081     1          1.9         1  13       1          42
# 259            1559     1          1.6         1   6       1           6
# 945             832     0          1.1         0   0       1          46
# ...             ...   ...          ...       ...  ..     ...         ...
# 500            1278     1          0.5         1   1       0          54
# 1837            983     0          0.6         1   0       1          45
# 941             743     0          0.5         1   0       1          33
# 421            1178     0          2.2         1   6       0          57
# 1829           1065     0          1.7         1   4       1          48
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
import pandas as pd
d=pd.read_csv("/content/sample_data/california_housing_train.csv")
d
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
d.describe()
d
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
type=d.dtypes
type
# Out:
# longitude             float64
# latitude              float64
# housing_median_age    float64
# total_rooms           float64
# total_bedrooms        float64
# population            float64
# households            float64
# median_income         float64
# median_house_value    float64
# dtype: object

# %%
shape=d.shape
shape
# Out:
# (17000, 9)

# %%
f=d['median_house_value']
f
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64

# %%
p=d.drop('median_house_value',axis=1)
p
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income
# ...

# %%
d.isnull()
d
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
i=p-p.min()/p.max()-p.min()
i
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       8.952169  0.874315           13.980769  5609.999947     1281.999845
# 1       8.792169  1.084315           17.980769  7647.999947     1899.999845
# 2       8.702169  0.374315           15.980769   717.999947      172.999845
# 3       8.692169  0.324315           12.980769  1498.999947      335.999845
# 4       8.692169  0.254315           18.980769  1451.999947      324.999845
# ...          ...       ...                 ...          ...             ...
# 16995  -0.997831  7.264315           50.980769  2214.999947      392.999845
# 16996  -1.007831  7.374315           34.980769  2346.999947      526.999845
# 16997  -1.037831  8.524315           15.980769  2674.999947      529.999845
# 16998  -1.037831  8.484315           17.980769  2669.999947      550.999845
# 16999  -1.087831  7.224315           50.980769  1817.999947      298.999845
#
#         population  households  median_income
# ...

# %%
from sklearn.model_selection import train_test_split
p_train,f_test,p_train,f_test= train_test_split(p,f,test_size=0.2,random_state=30)
print(p_train)
print(f_test)
print(p_train)
print(f_test)
# Out:
# 7303     170500.0
# 12831    248000.0
# 13976    254200.0
# 3268     182100.0
# 7206     133300.0
#            ...
# 500      154600.0
# 12077     93800.0
# 15277    235600.0
# 4517     338800.0
# 5925     186800.0
# Name: median_house_value, Length: 13600, dtype: float64
# 10914    127500.0
# 6241     261300.0
# 5904     192700.0
# 9578      62000.0
# 9444     396400.0
#            ...
# 12228     94600.0
# 6639     159600.0
# 7850     151600.0
# 4886     195800.0
# 3618     500001.0
# Name: median_house_value, Length: 3400, dtype: float64
# 7303     170500.0
# 12831    248000.0
# 13976    254200.0
# 3268     182100.0
# 7206     133300.0
#            ...
# 500      154600.0
# 12077     93800.0
# 15277    235600.0
# 4517     338800.0
# 5925     186800.0
# Name: median_house_value, Length: 13600, dtype: float64
# 10914    127500.0
# 6241     261300.0
# 5904     192700.0
# 9578      62000.0
# 9444     396400.0
#            ...
# 12228     94600.0
# 6639     159600.0
# ...
