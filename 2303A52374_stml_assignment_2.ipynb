# %% [markdown]
# <a href="https://colab.research.google.com/github/navaneethkomuravelli/2024_stml_assignments/blob/main/2303A52374_stml_assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Given the following dataset: X={1.3,1.5,2.6,2.6,3.2,3.9,4.2,3.7,3.10,3.0,11,6.7,1.9}. Compute the density of the data using a histogram with 5 bins.

# %%
import matplotlib.pyplot as plt
x=[1.3,1.5,2.6,2.6,3.2,3.9,4.2,3.7,3.10,3.0,11,6.7,1.9]
plt.hist(x,5)
# Out:
# (array([8., 3., 1., 0., 1.]),
#  array([ 1.3 ,  3.24,  5.18,  7.12,  9.06, 11.  ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
#  (dependent variables)
#
#  (independent variables)
#
# 12
#
# 51
#
# 13
#
# 63
#
# 56
#
# 37
#
# 23
#
# 88
#
# 41
#
# 33
#
# 28
#
# 72
#
# 51
#
# 81
#
#
#
# Find Mean, Median, Mode , Variance , Standard deviation , Range , Interquartile Range (IQR),  Skewness ,Kurtosis of x and y .

# %%
import numpy as np
import pandas as pd
X = [12,13,56,23,41,28,51] #dependent variables
Y = [51,63,37,88,33,72,81]#independent variables
x = np.array(X)
y = np.array(Y)
Q1 = np.percentile(x, 25)
Q3 = np.percentile(x, 75)
IQR = Q3-Q1
print("Quartile1 of x: ", Q1)
print("Quartile3 of x: ", Q3)
print("Interquartile range of x: ", IQR)
print("Mean of x: ", np.mean(x))
print("Mean of y: ", np.mean(y))
print("Median of x: ", np.median(x))
print("Median of y: ", np.median(y))
print("Variance of x: ", np.var(x))
print("Variance of y: ", np.var(y))
print("Standard deviation of x: ", np.std(x))
print("Standard deviation of y: ", np.std(y))
print("Range of x: ", np.ptp(x))
print("Range of x: ", np.ptp(y))
c = np.bincount(x)
m = np.argmax(c)
C = np.bincount(y)
M = np.argmax(C)
print("Mode of x: ", m)
print("Mode of y: ", M)
q1 = np.percentile(y, 25)
q3 = np.percentile(y, 75)
iqr = q3-q1
print("Quartile1 of y: ", q1)
print("Quartile3 of y: ", q3)
# Out:
# Quartile1 of x:  18.0
# Quartile3 of x:  46.0
# Interquartile range of x:  28.0
# Mean of x:  32.0
# Mean of y:  60.714285714285715
# Median of x:  28.0
# Median of y:  63.0
# Variance of x:  268.0
# Variance of y:  387.6326530612245
# Standard deviation of x:  16.3707055437449
# Standard deviation of y:  19.68838878784205
# Range of x:  44
# Range of x:  55
# Mode of x:  12
# Mode of y:  33
# Quartile1 of y:  44.0
# Quartile3 of y:  76.5

# %%
print("Interquartile range of y: ", iqr)
series = pd.Series(x)
skewn = series.skew()
print("Skewness of x: ", skewn)
ser = pd.Series(y)
ske = ser.skew()
print("Skewness of y: ", ske)
ser = pd.Series(x)
kurt = ser.kurt()
print("Kurtosis of x: ", kurt)
wser = pd.Series(y)
krt = wser.kurt()
print("Kurtosis of y: ", krt)
# Out:
# Interquartile range of y:  32.5
# Skewness of x:  0.24309548524609076
# Skewness of y:  -0.13169496617475043
# Kurtosis of x:  -1.7444165101995357
# Kurtosis of y:  -1.6236709987134375

# %% [markdown]
# From the above data Find Mean, Median, Mode, Variance, Standard deviation, Range , Interquartile Range (IQR),  Skewness ,Kurtosis of each feature.

# %%
#data analysis, question 3
import pandas as pd
import numpy as np
d = pd.read_csv("/content/sample_data/california_housing_train.csv")
print(d)
print(d['longitude'])
print("mean of langitude")
print(d.mean()['longitude'])
print("median of langitude")
print(d.median()['longitude'])
print("mode of langitude")
print(d.mode()['longitude'])
print("variance of langitude")
print(d.var()['longitude'])
print("standard deviation of langitude")
print(d.std()['longitude'])
print("range of langitude")
print(d.max()['longitude']-d.min()['longitude'])
print("interquartile range")
print(np.percentile(d['longitude'],75)-np.percentile(d['longitude'],25))
print("skewness")
print(d['longitude'].skew())
print("kurtosis")
print(d['longitude'].kurtosis())

print("        ")
print("latitude")
print(d['latitude'])
print("mean of latitude")
print(d.mean()['latitude'])
print("median of latitude")
print(d.median()['latitude'])
print("mode of latitude")
print(d.mode()['latitude'])
print("variance of latitude")
print(d.var()['latitude'])
print("standard deviation of latitude")
print(d.std()['latitude'])
print("range of latitude")
print(d.max()['latitude']-d.min()['latitude'])
print("interquartile range")
print(np.percentile(d['latitude'],75)-np.percentile(d['latitude'],25))
print("skewness")
print(d['latitude'].skew())
print("kurtosis")
print(d['latitude'].kurtosis())

print("          ")
print("husing_median_age")
print(d['housing_median_age'])
print("mean of housing_median_age")
print(d.mean()['housing_median_age'])
print("median of housing_median_age")
print(d.median()['housing_median_age'])
print("mode of housing_median_age")
print(d.mode()['housing_median_age'])
print("variance of housing_median_age")
print(d.var()['housing_median_age'])
print("standard deviation of housing_median_age")
print(d.std()['housing_median_age'])
print("range of housing_median_age")
print(d.max()['housing_median_age']-d.min()['housing_median_age'])
print("interquartile range")
print(np.percentile(d['housing_median_age'],75)-np.percentile(d['housing_median_age'],25))
print("skewness")
print(d['housing_median_age'].skew())
print("kurtosis")
print(d['housing_median_age'].kurtosis())
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income  median_house_value
# 0          1015.0       472.0         1.4936             66900.0
# 1          1129.0       463.0         1.8200             80100.0
# 2           333.0       117.0         1.6509             85700.0
# 3           515.0       226.0         3.1917             73400.0
# 4           624.0       262.0         1.9250             65500.0
# ...           ...         ...            ...                 ...
# 16995       907.0       369.0         2.3571            111400.0
# 16996      1194.0       465.0         2.5179             79000.0
# 16997      1244.0       456.0         3.0313            103600.0
# 16998      1298.0       478.0         1.9797             85800.0
# 16999       806.0       270.0         3.0147             94600.0
#
# [17000 rows x 9 columns]
# 0       -114.31
# 1       -114.47
# 2       -114.56
# 3       -114.57
# 4       -114.57
#           ...
# 16995   -124.26
# 16996   -124.27
# 16997   -124.30
# 16998   -124.30
# 16999   -124.35
# Name: longitude, Length: 17000, dtype: float64
# mean of langitude
# -119.5621082352941
# median of langitude
# -118.49
# mode of langitude
# 0   -118.31
# 1       NaN
# Name: longitude, dtype: float64
# variance of langitude
# 4.020692325480737
# standard deviation of langitude
# 2.0051664084261778
# range of langitude
# 10.039999999999992
# interquartile range
# 3.7900000000000063
# skewness
# -0.30400297675663496
# kurtosis
# -1.3223296680648942
#
# latitude
# 0        34.19
# 1        34.40
# 2        33.69
# 3        33.64
# 4        33.57
#          ...
# 16995    40.58
# 16996    40.69
# 16997    41.84
# 16998    41.80
# 16999    40.54
# Name: latitude, Length: 17000, dtype: float64
# mean of latitude
# 35.62522470588235
# median of latitude
# 34.25
# mode of latitude
# 0    34.06
# 1      NaN
# Name: latitude, dtype: float64
# variance of latitude
# 4.568221397824785
# standard deviation of latitude
# 2.1373397946570836
# range of latitude
# 9.410000000000004
# interquartile range
# 3.789999999999999
# skewness
# 0.4718011203585246
# kurtosis
# -1.1122264930558603
#
# husing_median_age
# 0        15.0
# 1        19.0
# 2        17.0
# 3        14.0
# 4        20.0
#          ...
# 16995    52.0
# 16996    36.0
# 16997    17.0
# 16998    19.0
# 16999    52.0
# Name: housing_median_age, Length: 17000, dtype: float64
# mean of housing_median_age
# 28.58935294117647
# median of housing_median_age
# 29.0
# mode of housing_median_age
# 0    52.0
# 1     NaN
# Name: housing_median_age, dtype: float64
# variance of housing_median_age
# 158.4309825802902
# standard deviation of housing_median_age
# 12.586936981660399
# range of housing_median_age
# 51.0
# interquartile range
# 19.0
# skewness
# 0.06489403293452067
# kurtosis
# -0.8008262246647506

# %%
print("          ")
print("total_rooms")
print(d['total_rooms'])
print("mean of total_rooms")
print(d.mean()['total_rooms'])
print("median of total_rooms")
print(d.median()['total_rooms'])
print("mode of total_rooms")
print(d.mode()['total_rooms'])
print("variance of total_rooms")
print(d.var()['total_rooms'])
print("standard deviation of total_rooms")
print(d.std()['total_rooms'])
print("range of total_rooms")
print(d.max()['total_rooms']-d.min()['total_rooms'])
print("interquartile range")
print(np.percentile(d['total_rooms'],75)-np.percentile(d['total_rooms'],25))
print("skewness")
print(d['total_rooms'].skew())
print("kurtosis")
print(d['total_rooms'].kurtosis())


print("          ")

print("total_bedrooms")
print(d['total_bedrooms'])
print("mean of total_bedrooms")
print(d.mean()['total_bedrooms'])
print("median of total_bedrooms")
print(d.median()['total_bedrooms'])
print("mode of total_bedrooms")
print(d.mode()['total_bedrooms'])
print("variance of total_bedrooms")
print(d.var()['total_bedrooms'])
print("standard deviation of total_bedrooms")
print(d.std()['total_bedrooms'])
print("range of total_bedrooms")
print(d.max()['total_bedrooms']-d.min()['total_bedrooms'])
print("interquartile range")
print(np.percentile(d['total_bedrooms'],75)-np.percentile(d['total_bedrooms'],25))
print("skewness")
print(d['total_bedrooms'].skew())
print("kurtosis")
print(d['total_bedrooms'].kurtosis())

print("              ")

print("population")
print(d['population'])
print("mean of population")
print(d.mean()['population'])
print("median of population")
print(d.median()['population'])
print("mode of population")
print(d.mode()['population'])
print("variance of population")
print(d.var()['population'])
print("standard deviation of population")
print(d.std()['population'])
print("range of population")
print(d.max()['population']-d.min()['population'])
print("interquartile range")
print(np.percentile(d['population'],75)-np.percentile(d['population'],25))
print("skewness")
print(d['population'].skew())
print("kurtosis")
print(d['population'].kurtosis())


print("          ")
print("households")
print(d['households'])
print("mean of households")
print(d.mean()['households'])
print("median of households")
print(d.median()['households'])
print("mode of households")
print(d.mode()['households'])
print("variance of households")
print(d.var()['households'])
print("standard deviation of households")
print(d.std()['households'])
print("range of households")
print(d.max()['households']-d.min()['households'])
print("interquartile range")
print(np.percentile(d['households'],75)-np.percentile(d['households'],25))
print("skewness")
print(d['households'].skew())
print("kurtosis")
print(d['households'].kurtosis())

print("              ")

print("median_income")
print(d['median_income'])
print("mean of median_income")
print(d.mean()['median_income'])
print("median of median_income")
print(d.median()['median_income'])
print("mode of median_income")
print(d.mode()['median_income'])
print("variance of median_income")
print(d.var()['median_income'])
print("standard deviation of median_income")
print(d.std()['median_income'])
print("range of median_income")
print(d.max()['median_income']-d.min()['median_income'])
print("interquartile range")
print(np.percentile(d['median_income'],75)-np.percentile(d['median_income'],25))
print("skewness")
print(d['median_income'].skew())
print("kurtosis")
print(d['median_income'].kurtosis())

print("               ")
print("median_house_value")
print(d['median_house_value'])
print("mean of median_house_value")
print(d.mean()['median_house_value'])
print("median of median_house_value")
print("mode of median_house_value")
print(d.mode()['median_house_value'])
print("variance of median_house_value")
print(d.var()['median_house_value'])
print("standard deviation of median_house_value")
print(d.std()['median_house_value'])
print("range of median_house_value")
print(d.max()['median_house_value']-d.min()['median_house_value'])
print("interquartile range")
print(np.percentile(d['median_income'],75)-np.percentile(d['median_income'],25))
print("skewness")
print(d['median_income'].skew())
print("kurtosis")
print(d['median_income'].kurtosis())
# Out:
#
# total_rooms
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64
# mean of total_rooms
# 2643.664411764706
# median of total_rooms
# 2127.0
# mode of total_rooms
# 0    1582.0
# 1       NaN
# Name: total_rooms, dtype: float64
# variance of total_rooms
# 4752169.234335496
# standard deviation of total_rooms
# 2179.947071452767
# range of total_rooms
# 37935.0
# interquartile range
# 1689.25
# skewness
# 4.002729998658741
# kurtosis
# 29.515884775650868
#
# total_bedrooms
# 0        1283.0
# 1        1901.0
# 2         174.0
# 3         337.0
# 4         326.0
#           ...
# 16995     394.0
# 16996     528.0
# 16997     531.0
# 16998     552.0
# 16999     300.0
# Name: total_bedrooms, Length: 17000, dtype: float64
# mean of total_bedrooms
# 539.4108235294118
# median of total_bedrooms
# 434.0
# mode of total_bedrooms
# 0    280.0
# 1      NaN
# Name: total_bedrooms, dtype: float64
# variance of total_bedrooms
# 177661.78768212663
# standard deviation of total_bedrooms
# 421.4994515798646
# range of total_bedrooms
# 6444.0
# interquartile range
# 351.25
# skewness
# 3.3226367155099132
# kurtosis
# 19.692750085289557
#
# population
# 0        1015.0
# 1        1129.0
# 2         333.0
# 3         515.0
# 4         624.0
#           ...
# 16995     907.0
# 16996    1194.0
# 16997    1244.0
# 16998    1298.0
# 16999     806.0
# Name: population, Length: 17000, dtype: float64
# mean of population
# 1429.5739411764705
# median of population
# 1167.0
# mode of population
# 0    891.0
# 1      NaN
# Name: population, dtype: float64
# variance of population
# 1317566.4158512817
# standard deviation of population
# 1147.8529591595266
# range of population
# 35679.0
# interquartile range
# 931.0
# skewness
# 5.187211878247974
# kurtosis
# 80.86199702158139
#
# households
# 0        472.0
# 1        463.0
# 2        117.0
# 3        226.0
# 4        262.0
#          ...
# 16995    369.0
# 16996    465.0
# 16997    456.0
# 16998    478.0
# 16999    270.0
# Name: households, Length: 17000, dtype: float64
# mean of households
# 501.2219411764706
# median of households
# 409.0
# mode of households
# 0    306.0
# 1    386.0
# Name: households, dtype: float64
# variance of households
# 147856.27705252904
# standard deviation of households
# 384.5208408559009
# range of households
# 6081.0
# interquartile range
# 323.25
# skewness
# 3.3426683625335154
# kurtosis
# 20.69264454575972
#
# median_income
# 0        1.4936
# 1        1.8200
# 2        1.6509
# 3        3.1917
# 4        1.9250
#           ...
# 16995    2.3571
# 16996    2.5179
# 16997    3.0313
# 16998    1.9797
# 16999    3.0147
# Name: median_income, Length: 17000, dtype: float64
# mean of median_income
# 3.8835781000000007
# median of median_income
# 3.5446
# mode of median_income
# 0    3.125
# 1      NaN
# Name: median_income, dtype: float64
# variance of median_income
# 3.6410612986326623
# standard deviation of median_income
# 1.9081565183791036
# range of median_income
# 14.5002
# interquartile range
# 2.2006250000000005
# skewness
# 1.6266930979614043
# kurtosis
# 4.764144930324816
#
# median_house_value
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64
# mean of median_house_value
# 207300.91235294117
# median of median_house_value
# mode of median_house_value
# 0    500001.0
# 1         NaN
# Name: median_house_value, dtype: float64
# variance of median_house_value
# 13452233601.427578
# standard deviation of median_house_value
# 115983.76438720885
# range of median_house_value
# 485002.0
# interquartile range
# 2.2006250000000005
# skewness
# 1.6266930979614043
# kurtosis
# 4.764144930324816

# %%
print("          ")
print("total_rooms")
print(d['total_rooms'])
print("mean of total_rooms")
print(d.mean()['total_rooms'])
print("median of total_rooms")
print(d.median()['total_rooms'])
print("mode of total_rooms")
print(d.mode()['total_rooms'])
print("variance of total_rooms")
print(d.var()['total_rooms'])
print("standard deviation of total_rooms")
print(d.std()['total_rooms'])
print("range of total_rooms")
print(d.max()['total_rooms']-d.min()['total_rooms'])
print("interquartile range")
print(np.percentile(d['total_rooms'],75)-np.percentile(d['total_rooms'],25))
print("skewness")
print(d['total_rooms'].skew())
print("kurtosis")
print(d['total_rooms'].kurtosis())


print("          ")

print("total_bedrooms")
print(d['total_bedrooms'])
print("mean of total_bedrooms")
print(d.mean()['total_bedrooms'])
print("median of total_bedrooms")
print(d.median()['total_bedrooms'])
print("mode of total_bedrooms")
print(d.mode()['total_bedrooms'])
print("variance of total_bedrooms")
print(d.var()['total_bedrooms'])
print("standard deviation of total_bedrooms")
print(d.std()['total_bedrooms'])
print("range of total_bedrooms")
print(d.max()['total_bedrooms']-d.min()['total_bedrooms'])
print("interquartile range")
print(np.percentile(d['total_bedrooms'],75)-np.percentile(d['total_bedrooms'],25))
print("skewness")
print(d['total_bedrooms'].skew())
print("kurtosis")
print(d['total_bedrooms'].kurtosis())

print("              ")

print("population")
print(d['population'])
print("mean of population")
print(d.mean()['population'])
print("median of population")
print(d.median()['population'])
print("mode of population")
print(d.mode()['population'])
print("variance of population")
print(d.var()['population'])
print("standard deviation of population")
print(d.std()['population'])
print("range of population")
print(d.max()['population']-d.min()['population'])
print("interquartile range")
print(np.percentile(d['population'],75)-np.percentile(d['population'],25))
print("skewness")
print(d['population'].skew())
print("kurtosis")
print(d['population'].kurtosis())


print("          ")
print("households")
print(d['households'])
print("mean of households")
print(d.mean()['households'])
print("median of households")
print(d.median()['households'])
print("mode of households")
print(d.mode()['households'])
print("variance of households")
print(d.var()['households'])
print("standard deviation of households")
print(d.std()['households'])
print("range of households")
print(d.max()['households']-d.min()['households'])
print("interquartile range")
print(np.percentile(d['households'],75)-np.percentile(d['households'],25))
print("skewness")
print(d['households'].skew())
print("kurtosis")
print(d['households'].kurtosis())

print("              ")

print("median_income")
print(d['median_income'])
print("mean of median_income")
print(d.mean()['median_income'])
print("median of median_income")
print(d.median()['median_income'])
print("mode of median_income")
print(d.mode()['median_income'])
print("variance of median_income")
print(d.var()['median_income'])
print("standard deviation of median_income")
print(d.std()['median_income'])
print("range of median_income")
print(d.max()['median_income']-d.min()['median_income'])
print("interquartile range")
print(np.percentile(d['median_income'],75)-np.percentile(d['median_income'],25))
print("skewness")
print(d['median_income'].skew())
print("kurtosis")
print(d['median_income'].kurtosis())

print("               ")
print("median_house_value")
print(d['median_house_value'])
print("mean of median_house_value")
print(d.mean()['median_house_value'])
print("median of median_house_value")
print("mode of median_house_value")
print(d.mode()['median_house_value'])
print("variance of median_house_value")
print(d.var()['median_house_value'])
print("standard deviation of median_house_value")
print(d.std()['median_house_value'])
print("range of median_house_value")
print(d.max()['median_house_value']-d.min()['median_house_value'])
print("interquartile range")
print(np.percentile(d['median_income'],75)-np.percentile(d['median_income'],25))
print("skewness")
print(d['median_income'].skew())
print("kurtosis")
print(d['median_income'].kurtosis())
# Out:
#
# total_rooms
# 0        5612.0
# 1        7650.0
# 2         720.0
# 3        1501.0
# 4        1454.0
#           ...
# 16995    2217.0
# 16996    2349.0
# 16997    2677.0
# 16998    2672.0
# 16999    1820.0
# Name: total_rooms, Length: 17000, dtype: float64
# mean of total_rooms
# 2643.664411764706
# median of total_rooms
# 2127.0
# mode of total_rooms
# 0    1582.0
# 1       NaN
# Name: total_rooms, dtype: float64
# variance of total_rooms
# 4752169.234335496
# standard deviation of total_rooms
# 2179.947071452767
# range of total_rooms
# 37935.0
# interquartile range
# 1689.25
# skewness
# 4.002729998658741
# kurtosis
# 29.515884775650868
#
# total_bedrooms
# 0        1283.0
# 1        1901.0
# 2         174.0
# 3         337.0
# 4         326.0
#           ...
# 16995     394.0
# 16996     528.0
# 16997     531.0
# 16998     552.0
# 16999     300.0
# Name: total_bedrooms, Length: 17000, dtype: float64
# mean of total_bedrooms
# 539.4108235294118
# median of total_bedrooms
# 434.0
# mode of total_bedrooms
# 0    280.0
# 1      NaN
# Name: total_bedrooms, dtype: float64
# variance of total_bedrooms
# 177661.78768212663
# standard deviation of total_bedrooms
# 421.4994515798646
# range of total_bedrooms
# 6444.0
# interquartile range
# 351.25
# skewness
# 3.3226367155099132
# kurtosis
# 19.692750085289557
#
# population
# 0        1015.0
# 1        1129.0
# 2         333.0
# 3         515.0
# 4         624.0
#           ...
# 16995     907.0
# 16996    1194.0
# 16997    1244.0
# 16998    1298.0
# 16999     806.0
# Name: population, Length: 17000, dtype: float64
# mean of population
# 1429.5739411764705
# median of population
# 1167.0
# mode of population
# 0    891.0
# 1      NaN
# Name: population, dtype: float64
# variance of population
# 1317566.4158512817
# standard deviation of population
# 1147.8529591595266
# range of population
# 35679.0
# interquartile range
# 931.0
# skewness
# 5.187211878247974
# kurtosis
# 80.86199702158139
#
# households
# 0        472.0
# 1        463.0
# 2        117.0
# 3        226.0
# 4        262.0
#          ...
# 16995    369.0
# 16996    465.0
# 16997    456.0
# 16998    478.0
# 16999    270.0
# Name: households, Length: 17000, dtype: float64
# mean of households
# 501.2219411764706
# median of households
# 409.0
# mode of households
# 0    306.0
# 1    386.0
# Name: households, dtype: float64
# variance of households
# 147856.27705252904
# standard deviation of households
# 384.5208408559009
# range of households
# 6081.0
# interquartile range
# 323.25
# skewness
# 3.3426683625335154
# kurtosis
# 20.69264454575972
#
# median_income
# 0        1.4936
# 1        1.8200
# 2        1.6509
# 3        3.1917
# 4        1.9250
#           ...
# 16995    2.3571
# 16996    2.5179
# 16997    3.0313
# 16998    1.9797
# 16999    3.0147
# Name: median_income, Length: 17000, dtype: float64
# mean of median_income
# 3.8835781000000007
# median of median_income
# 3.5446
# mode of median_income
# 0    3.125
# 1      NaN
# Name: median_income, dtype: float64
# variance of median_income
# 3.6410612986326623
# standard deviation of median_income
# 1.9081565183791036
# range of median_income
# 14.5002
# interquartile range
# 2.2006250000000005
# skewness
# 1.6266930979614043
# kurtosis
# 4.764144930324816
#
# median_house_value
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64
# mean of median_house_value
# 207300.91235294117
# median of median_house_value
# mode of median_house_value
# 0    500001.0
# 1         NaN
# Name: median_house_value, dtype: float64
# variance of median_house_value
# 13452233601.427578
# standard deviation of median_house_value
# 115983.76438720885
# range of median_house_value
# 485002.0
# interquartile range
# 2.2006250000000005
# skewness
# 1.6266930979614043
# kurtosis
# 4.764144930324816
